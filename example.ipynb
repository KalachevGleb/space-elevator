# %%
from space_elevator import *

t = UniformStressTether()

sp = t.spectrum()
for i in range(0, 21, 5):
    print(f't_eq[{i}] = {sp.period_eq(i,"h")}, t_mer[{i}] = {sp.period_mer(i,"h")}')
    sp.show_mode(i)
# Out:
# t_eq[0] = 138.2493510528306, t_mer[0] = 23.584013501436406
# t_eq[5] = 1.6145895784796593, t_mer[5] = 1.6109284421510979
# t_eq[10] = 0.8099213961477914, t_mer[10] = 0.8094580938709403
# t_eq[15] = 0.5404482278613945, t_mer[15] = 0.5403105053768621
# t_eq[20] = 0.40549144113652974, t_mer[20] = 0.40543326294853504
